# %% [markdown]
# <a href="https://colab.research.google.com/github/aghnan9-rgb/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_persegi_panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tugas membuat menghitung bangun datar luas persegi panjang
# nama kelompok :nexacode
#
# 1. aghnan
# 2. fadhil
# 3. davi
# 4. raisya
# 5. dina
# 6. nurma
# 7. alya

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luaspersegipanjang.cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float panjang, lebar, luas;
#
#     cout << "masukan panjang: ";
#     cin >> panjang;
#     cout << "masukan lebar: ";
#     cin >> lebar;
#
#     luas = panjang * lebar;
#     cout << "luas persegi panjang = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting luaspersegipanjang.cpp

# %%
# !g++ ./luaspersegipanjang.cpp -o main

# %%
! ./main
# Out:
# masukan panjang: ^C
