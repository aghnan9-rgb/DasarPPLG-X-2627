# %% [markdown]
# <a href="https://colab.research.google.com/github/aghnan9-rgb/DasarPPLG-X-2627/blob/main/X_PPLG_AGHNAN_AISZAR_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 1 PRAKTIK MEMBUAT TIPE DATA DAN VARIABEL
#
# NAMA KELOMPOK: NEXACODE
# Nama anggota :
# 1. aghnan aiszar kamaludin
# 2. davi ramadhan pratama
# 3. teuku muhammad fadhil
# 4. alyaa rahama thalita
# 5. raisya putri darmawan
# 6. nurmawadah
# 7. Syafira meidina syarif

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     // Deklarasi Variabel dan Tipe Data
#     string namaBarang = "Sepatu Adidas Ultraboost";
#     int jumlah = 30;
#     double harga = 2900000.50;
#     char kategori = 'C';
#     bool tersedia = true;
#
#     // Menampilkan Output ke Layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia << " (1 = Ya, 0 = Tidak)" << endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel

# %%
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Sepatu Adidas Ultraboost
# Kategori    : C
# Jumlah      : 30
# Harga       : Rp 2.9e+06
# Tersedia    : 1 (1 = Ya, 0 = Tidak)
# ...
