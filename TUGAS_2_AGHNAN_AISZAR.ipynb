# %% [markdown]
# <a href="https://colab.research.google.com/github/aghnan9-rgb/DasarPPLG-X-2627/blob/main/TUGAS_2_AGHNAN_AISZAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS 2 PRAKTIK INPUT DATA
#
# NAMA KELOMPOK : NEXACODE
# NAMA ANGGOTA :
#
# 1. aghnan aiszar kamaludin
# 2. davi Ramadhan Pratama
# 3. teuku muhammad fadhil
# 4. raisya putri darmawan
# 5. alyaa rahma thalita
# 6. nurmawadah
# 7. syafira meidina syarif

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Writing input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
! ./input_data
# Out:
# Masukkan Nama (1 Kata) : aghnan
# Masukkan Umur Anda     : 16
#
# Halo aghnan, ternyata umur kamu 16 tahun ya!
